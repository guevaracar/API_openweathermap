# %% [markdown]
# # Analysis

# %% [markdown]
#     Observed Trend 1: Temperature increases as you get closer to the Equator.
#     Observed Trend 2: When Humidity increases, temperature also increases.
#     Observed Trend 3: The majority of the cities are located from Latitude: -40,40.

# %%
import json 
import requests
import matplotlib.pyplot as plt
import pandas as pd
import numpy as np
import random
import openweathermapy.core as ow
from citipy import citipy
import seaborn as sns
from config import api_key

# %%
lat = []
lon = []
cities = set([])

while len(cities) < 1500:
    lati = (random.randrange(-90,90,1))
    long = (random.randrange(-180,180,1))
    city = citipy.nearest_city(lati,long)
    city = city.city_name
    lat.append(lati)
    lon.append(long)
    cities.add(city)
    
cities = list(cities)

# %%
#api key
setting = {"units": "IMPERIAL", "appid": api_key}

# %%
weather_data = []
counter = []
count = 0

for city in cities:
    if count < 500:
        try:
            data = ow.get_current(city, **setting)
            weather_data.append(data)
            count = count + 1
            counter.append(count)
        except Exception as e:
            print(f"{city}: {e}, no weather data")
            continue
# Out:
# ust-kamchatsk: HTTP Error 404: Not Found, no weather data
# amderma: HTTP Error 404: Not Found, no weather data
# karakendzha: HTTP Error 404: Not Found, no weather data
# okandja: HTTP Error 404: Not Found, no weather data
# jiuquan: HTTP Error 404: Not Found, no weather data
# paytug: HTTP Error 404: Not Found, no weather data
# bocaranga: HTTP Error 404: Not Found, no weather data
# yaan: HTTP Error 404: Not Found, no weather data
# belushya guba: HTTP Error 404: Not Found, no weather data
# da nang: HTTP Error 404: Not Found, no weather data
# lemesos: HTTP Error 404: Not Found, no weather data
# meyungs: HTTP Error 404: Not Found, no weather data
# chagda: HTTP Error 404: Not Found, no weather data
# olafsvik: HTTP Error 404: Not Found, no weather data
# longlac: HTTP Error 404: Not Found, no weather data
# abu samrah: HTTP Error 404: Not Found, no weather data
# sahrak: HTTP Error 404: Not Found, no weather data
# falealupo: HTTP Error 404: Not Found, no weather data
# ...

# %%
#weather_data

# %%
summary = ["name", "dt", "sys.country", "main.temp_max", "coord.lat", "main.humidity", "clouds.all", "wind.speed"]
data = [response(*summary) for response in weather_data]
column_names = ["City", "Time", "Country", "Temperature", "Latitude", "Humidity", "Cloud Cover", "Wind Speed"]
weather_data = pd.DataFrame(data, index=counter, columns=column_names)
weather_data.head()
# Out:
#              City        Time Country  Temperature  Latitude  Humidity  \
# 1    Chiang Klang  1511041658      TH        69.09     19.29        91
# 2          Rjukan  1511041659      NO        27.24     59.88       100
# 3  Port Elizabeth  1511041660      ZA        64.32    -33.92       100
# 4          Xifeng  1511041660      CN        -6.52     42.74        58
# 5      Phan Thiet  1511041661      VN        74.89     10.93       100
#
#    Cloud Cover  Wind Speed
# 1           88        2.13
# 2           24        7.94
# 3            0        8.05
# 4            0        2.57
# 5           92       12.19

# %%
weather_df = weather_data
#weather_df.to_csv("weather_data.csv")

# %%
plt.scatter(weather_data["Latitude"], weather_data["Temperature"], marker="o")
plt.title("Latitude in World Cities v. Temperature")
plt.ylabel("Temperature (F)")
plt.xlabel("Latitude")
plt.grid(True)
plt.show()

# %%
plt.scatter(weather_data["Latitude"], weather_data["Humidity"], marker="o")
plt.title("Latitude in World Cities v. Humidity")
plt.ylabel("Humidity")
plt.xlabel("Latitude")
plt.grid(True)
plt.show()

# %%
plt.scatter(weather_data["Latitude"], weather_data["Cloud Cover"], marker="o")
plt.title("Latitude in World Cities v. Cloud Cover")
plt.ylabel("Cloud Cover")
plt.xlabel("Latitude")
plt.grid(True)
plt.show()

# %%
plt.scatter(weather_data["Latitude"], weather_data["Wind Speed"], marker="o")
plt.title("Latitude in World Cities v. Wind Speed")
plt.ylabel("Wind Speed")
plt.xlabel("Latitude")
plt.grid(True)
plt.show()

# %%
plt.scatter(weather_data["Temperature"], weather_data["Humidity"], marker="o")
plt.title("Temperature v. Humidity")
plt.ylabel("Humidity")
plt.xlabel("Temperature")
plt.grid(True)
plt.show()

# %%
plt.scatter(weather_data["Temperature"], weather_data["Wind Speed"], marker="o")
plt.title("Temperature v. Wind Speed")
plt.ylabel("Wind Speed")
plt.xlabel("Temperature")
plt.grid(True)
plt.show()

# %%
plt.scatter(weather_data["Wind Speed"], weather_data["Temperature"], marker="o")
plt.title("Wind Speed v. Temperature")
plt.xlabel("Wind Speed")
plt.ylabel("Temperature")
plt.grid(True)
plt.show()

# %%
plt.scatter(weather_data["Temperature"], weather_data["Cloud Cover"], marker="o")
plt.title("Temperature v. Cloud Cover")
plt.ylabel("Cloud Cover")
plt.xlabel("Temperature")
plt.grid(True)
plt.show()
